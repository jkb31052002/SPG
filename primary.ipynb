# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Copy of Survey On Social Media Usage (Responses) - Form Responses 1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 42 columns):
#  #   Column                                                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                                                               --------------  -----
#  0   Timestamp                                                                                                                                                                            144 non-null    object
#  1   Gmail or any nick name                                                                                                                                                               137 non-null    object
# ...

# %%
import matplotlib.pyplot as plt

# Plot the distribution of a particular column
df['column_name'].value_counts().plot(kind='bar')
plt.show()

# Plot the relationship between two columns
plt.scatter(df['column_1'], df['column_2'])
plt.xlabel('column_1')
plt.ylabel('column_2')
plt.show()

# Create a pie chart of a particular column
df['column_name'].value_counts().plot(kind='pie')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       1 import matplotlib.pyplot as plt
# ...

# %%
df['Gender'].value_counts().plot(kind='pie')
plt.show()

# %%
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
df['Age'].value_counts().plot(kind='bar', color='orange')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')

# Display the percentage values on top of each bar
for index, value in enumerate(df['Age'].value_counts()):
    plt.text(index, value + 1, f'{value / len(df["Age"]) * 100:.1f}%', ha='center', va='bottom')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

plt.figure(figsize=(10, 6))
sns.stripplot(x='Gender', y='What’s your Education Level?', data=df, jitter=True, palette='viridis')
plt.title('Scatter Plot of Gender and Education Level')
plt.xlabel('Gender')
plt.ylabel('What’s your Education Level?')
plt.show()
# Out:
# <ipython-input-15-11d55554c67b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Gender', y='What’s your Education Level?', data=df, jitter=True, palette='viridis')

# %%
df['Gender'].value_counts().plot(kind='bar', color=['skyblue', 'pink'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(x='How often do you use social media platforms in a typical day?', y='Age', data=df, palette='pastel')
plt.title('Age vs. Social Media Usage Frequency')
plt.xlabel('Social Media Usage Frequency')
plt.ylabel('Age')
plt.show()
# Out:
# <ipython-input-17-f36739e19308>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='How often do you use social media platforms in a typical day?', y='Age', data=df, palette='pastel')

# %%
gender_social_media = df.groupby(['Gender', 'How often do you use social media platforms in a typical day?']).size().unstack()
gender_social_media.plot(kind='bar', stacked=True, color=['lightblue', 'lightcoral', 'lightgreen'])
plt.title('Gender Distribution in Social Media Usage Frequency')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Create a new DataFrame to store the counts for each combination
edu_level_vs_usage = df.groupby(['What’s your Education Level?', 'How often do you use social media platforms in a typical day?']).size().unstack()

# Plotting a grouped bar chart
ax = edu_level_vs_usage.plot(kind='bar', figsize=(12, 8), colormap='viridis')

# Adding data labels
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Education Level vs. Social Media Usage Frequency')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# %%
import numpy as np

# Grouping data
gender_platform = df.groupby(['Gender', 'Which social media do you use most?']).size().unstack()

# Plotting
ax = gender_platform.plot(kind='bar', color=['blue', 'green', 'orange', 'yellow', 'red', 'purple', 'lightblue'], figsize=(10, 6))

# Adding data labels
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Preferred Social Media Platforms by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
age_subscription = df.groupby(['Age', 'Do you pay for any Social Media Subscription like Blue tick on Instagram or X?']).size().unstack()
age_subscription.plot(kind='bar', stacked=True, color=['lightblue', 'lightgreen'])
plt.title('Subscription Payment by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %%
df['What is your profession ?'].value_counts().plot(kind='barh', color='lightgreen')
plt.title('Distribution of Professions')
plt.xlabel('Count')
plt.ylabel('Profession')
plt.show()

# %%
df['How often do you post anything on Social Media ?'].value_counts().plot(kind='bar', color='lightpink')
plt.title('Frequency of Social Media Posts')
plt.xlabel('Frequency')
plt.ylabel('Count')
plt.show()

# %%
df['Do you pay for any Social Media Subscription like Blue tick on Instagram or X?'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'])
plt.title('Subscription Payment')
plt.ylabel('')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

gender_profession = df.groupby(['Gender', 'What is your profession ?']).size().unstack()
ax = gender_profession.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='Set2')

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height + 0.1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Gender vs. Profession')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Gender', y='Age', data=df, palette='pastel')

# Adding data labels next to data points
medians = df.groupby('Gender')['Age'].median().values
nobs = df['Gender'].value_counts().values
nobs = [f"n: {i}" for i in nobs]

for i in range(len(medians)):
    plt.text(i, medians[i] + 0.1, nobs[i], ha='center', va='bottom', color='black', fontsize=8)

plt.title('Gender vs. Age')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()
# Out:
# <ipython-input-39-9630838d0573>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='Age', data=df, palette='pastel')
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1790             try:
# -> 1791                 result = self.grouper._cython_operation(
#    1792                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038         ngroups = self.ngroups
# -> 1039         return cy_op.cython_operation(
#    1040             values=values,
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Gender', hue='How often do you use social media platforms in a typical day?', data=df, palette='viridis')

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.annotate(f'{height}', (x + width/2, y + height + 1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Gender vs. Social Media Usage Frequency')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
gender_subscription = df.groupby(['Gender', 'Do you pay for any Social Media Subscription like Blue tick on Instagram or X?']).size().unstack()
ax = gender_subscription.plot(kind='bar', stacked=True, colormap='Accent', figsize=(12, 8))

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height + 0.1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Gender vs. Social Media Subscription')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

gender_education = df.groupby(['Gender', 'What’s your Education Level?']).size().unstack()
ax = gender_education.plot(kind='bar', figsize=(12, 8), colormap='Set3')

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height + 0.1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Gender vs. Education Level')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', hue='Gender', bins=20, multiple='stack', palette='pastel')

plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
gender_social_media_management = df.groupby(['Gender', 'Do you actively manage your social media usage to avoid negative impacts on your work life?']).size().unstack()
ax = gender_social_media_management.plot(kind='bar', stacked=True, colormap='Accent', figsize=(12, 8))

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height + 0.1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Gender vs. Active Social Media Management')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='Gender', hue='Have you ever experienced any negative consequences of using social media that impacted your studies?', data=df, palette='viridis')

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.annotate(f'{height}', (x + width/2, y + height + 1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Gender vs. Negative Consequences of Social Media')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.boxplot(x='What is your profession ?', y='Age', data=df, palette='Set2')

# Adding data labels next to data points
medians = df.groupby('What is your profession ?')['Age'].median().values
nobs = df['What is your profession ?'].value_counts().values
nobs = [f"n: {i}" for i in nobs]

for i in range(len(medians)):
    plt.text(i, medians[i] + 0.1, nobs[i], ha='center', va='bottom', color='black', fontsize=8)

plt.title('Profession vs. Age')
plt.xlabel('Profession')
plt.ylabel('Age')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# <ipython-input-47-4853af7b7e29>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='What is your profession ?', y='Age', data=df, palette='Set2')
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1790             try:
# -> 1791                 result = self.grouper._cython_operation(
#    1792                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038         ngroups = self.ngroups
# -> 1039         return cy_op.cython_operation(
#    1040             values=values,
#
# ...

# %%
edu_content_creator = df.groupby(['What’s your Education Level?', 'Have you ever considered transitioning into a career as a social media content creator, specifically focusing on creating and sharing content on social media platforms?']).size().unstack()
ax = edu_content_creator.plot(kind='bar', stacked=True, colormap='Accent', figsize=(12, 8))

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height + 0.1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Education Level vs. Considering Career as Content Creator')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(x='What is your profession ?', hue='Have you ever experienced any negative consequences of using social media that impacted your studies?', data=df, palette='viridis')

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.annotate(f'{height}', (x + width/2, y + height + 1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Profession vs. Negative Consequences of Social Media')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
profession_social_media = df.groupby(['What is your profession ?', 'How often do you use social media platforms in a typical day?']).size().unstack()
ax = profession_social_media.plot(kind='bar', figsize=(16, 10), colormap='Paired')

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height}', (x + width/2, y + height + 0.1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Profession vs. Social Media Usage Frequency')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
sns.countplot(x='Gender', hue='Are you interested in pursuing a career in the new age economy (e.g., online businesses, gig economy, creator economy)?', data=df, palette='viridis')

# Adding data labels above bars
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.annotate(f'{height}', (x + width/2, y + height + 1), ha='center', va='bottom', fontsize=8, color='black')

plt.title('Gender vs. Considering Career in New Age Economy')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
